# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bloodreports_data.csv')

# %%
df.isnull()
# Out:
#        S.NO   Name    WBC    RBC    HGB    PLT  ANEHBC  ANERBC  \
# 0     False  False  False  False  False  False   False   False
# 1     False  False  False  False  False  False   False   False
# 2     False  False  False  False  False  False   False   False
# 3     False  False  False  False  False  False   False   False
# 4     False  False  False  False  False  False   False   False
# 5     False  False  False  False  False  False   False   False
# 6     False  False  False  False  False  False   False   False
# 7     False  False  False  False  False  False   False   False
# 8     False  False  False  False  False  False   False   False
# 9     False  False  False  False  False  False   False   False
# 10    False  False  False  False  False  False   False   False
# 11    False  False  False  False  False  False   False   False
# 12    False  False  False  False  False  False   False   False
# 13    False  False  False  False  False  False   False   False
# ...

# %%
df.isnull().sum()
# Out:
# S.NO                0
# Name                7
# WBC                 0
# RBC                 0
# HGB                 0
# PLT                 0
# ANEHBC              0
# ANERBC              0
# THROMBOCYTOPENIA    0
# LEUKOCYTOSIS        0
# NORMAL              0
# Phone Number        0
# dtype: int64

# %%
df.shape
# Out:
# (1199, 12)

# %%
df.dropna(subset=['Name'],how="any").shape
# Out:
# (1192, 12)

# %%
df.head()
# Out:
#    S.NO               Name   WBC  RBC   HGB   PLT  ANEHBC  ANERBC  \
# 0     1  G.Vasu deva naidu   6.9  5.7  17.6  2.07       2       2
# 1     2             V.Vasu  10.1  4.9  15.3  2.78       2       2
# 2     3         G.Babu rao   7.2  4.7  15.9  2.17       2       2
# 3     4          P.Pradeep   7.0  3.8  14.6  1.62       2       2
# 4     5       P.Ravi Kiran   6.4  4.7  16.6  2.23       2       2
#
#    THROMBOCYTOPENIA  LEUKOCYTOSIS NORMAL Phone Number
# 0                 2             2      N   9492576855
# 1                 2             1      N   9398520812
# 2                 2             2      N   8688104885
# 3                 1             2      N   6301612078
# 4                 2             2      N   9542156312

# %%
NT_df=df[df['THROMBOCYTOPENIA']==2]
YT_df=df[df['THROMBOCYTOPENIA']==1]
axes=NT_df.plot(kind='scatter', x='RBC',y='HGB',color='green',label='nane')
YT_df.plot(kind='scatter', x='RBC',y='HGB',color='red',label='yane',ax=axes)

# %%
NT_df=df[df['ANEHBC']==2]
YT_df=df[df['ANEHBC']==1]
axes=NT_df.plot(kind='scatter', x='RBC',y='HGB',color='green',label='nane')
YT_df.plot(kind='scatter', x='RBC',y='HGB',color='red',label='yane',ax=axes)

# %%
NT_df=df[df['LEUKOCYTOSIS']==2]
YT_df=df[df['LEUKOCYTOSIS']==1]
axes=NT_df.plot(kind='scatter', x='RBC',y='HGB',color='green',label='nane')
YT_df.plot(kind='scatter', x='RBC',y='HGB',color='red',label='yane',ax=axes)

# %%
x=0;
d1=0;
d2=0;
d3=0;
s1="Person is healthy condition"
s2="Consult doctor immediatly"
s3="Need to take precautions"

# %%
print(d1)
# Out:
# 0

# %%
df.columns
feature_df=df[ ['WBC', 'RBC', 'HGB','PLT']]
X= np.asarray(feature_df)
z=np.asarray(df['ANERBC'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,z_train,z_test=train_test_split(X,z,test_size=0.2,random_state=3)
X_test.shape
z_test.shape
# Out:
# (240,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
st_x= StandardScaler()    
X_train= st_x.fit_transform(X_train)    
X_test= st_x.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.49340174,  0.63412652,  1.3491434 ,  0.25064374],
#        [ 0.33283621, -0.11294066, -0.51247403, -0.55771085],
#        [-0.10511304,  0.18002686, -0.68872184, -0.39603993],
#        ...,
#        [-0.35536976,  0.16537849, -1.05223293,  1.05899833],
#        [ 0.92719592, -0.43520493, -0.7217683 , -0.08513432],
#        [-0.32408767,  0.60482977, -0.46841208, -1.12977718]])

# %%
from sklearn import svm
classifier=svm.SVC(kernel='linear',gamma='auto',C=2)
classifier.fit(X_train,z_train) 
z_predict=classifier.predict(X_test)

# %%
if(classifier.predict([[11.7,4.28,10.7,4.63]]))==1:
            print('person  have Anemia')
            x=x+1;
            d1=d1+1;
else:
            print('person may NOT have Anemia')
# Out:
# person may NOT have Anemia

# %%
df.columns
feature_df=df[ ['WBC', 'RBC', 'HGB','PLT']]
X= np.asarray(feature_df)
z=np.asarray(df['THROMBOCYTOPENIA'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,z_train,z_test=train_test_split(X,z,test_size=0.2,random_state=3)
X_test.shape
z_test.shape
# Out:
# (240,)

# %%
from sklearn import svm
classifier=svm.SVC(kernel='linear',gamma='auto',C=2)
classifier.fit(X_train,z_train) 
z_predict=classifier.predict(X_test)

# %%
if(classifier.predict([[11.7,4.28,10.7,4.63]]))==1:
            print('person  have thrombo')
            x=x+1;
            d2=d2+1;
else:
            print('person may NOT have thrombo')
# Out:
# person may NOT have thrombo

# %%
df.columns
feature_df=df[ ['WBC', 'RBC', 'HGB','PLT']]
X= np.asarray(feature_df)
z=np.asarray(df['LEUKOCYTOSIS'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,z_train,z_test=train_test_split(X,z,test_size=0.2,random_state=3)
X_test.shape
z_test.shape
# Out:
# (240,)

# %%
from sklearn import svm
classifier=svm.SVC(kernel='linear',gamma='auto',C=2)
classifier.fit(X_train,z_train) 
z_predict=classifier.predict(X_test)

# %%
if(classifier.predict([[11.7,4.28,10.7,4.63]]))==1:
            print('person  have leukocytosis')
            x=x+1;
            d3=d3+1;
else:
            print('person may NOT have leukocytosis')
# Out:
# person may NOT have leukocytosis

# %%
if x==0:
    output=''+s1
elif x==3:
    output=''+s2
else:
    if d1==1 and d2==1 :
        output=''+s3+ " person have low platletcount and low red blood cells"
    elif d2==1 and d3==1 :
        output=''+s3+ " person have low red blood cells and high white blood cells"
    elif d3==1 and d1==1 :
        output=''+s3+ " person have high white blood cells and low platletcount"
    elif d1==1:
        output=''+s3+ " :follow healthy diet,exercising regularly"
    elif d2==1:
        output=''+s3+ " :Avoid procedures that may cause a break in the skin,wear shoes to protect your feet"
    else:
        output=''+s3+ " :Maintaining healthy lifestyle,wash your hands regularly"

# %%
print(output)
# Out:
# Person is healthy condition

# %%
from twilio.rest import Client

# %%
Client=Client("AC7c7939904655f76a4b4d6ea8bc52dc86","977c16b8d4efcd6bad18b3fe7def117f")

# %%
Client.messages.create(to=["+919398520822"],from_="+1 9202640317",body=output)
# Out:
# <Twilio.Api.V2010.MessageInstance account_sid=AC7c7939904655f76a4b4d6ea8bc52dc86 sid=SM745dceedde3346e8ba1d1dd9b0a3f9da>

# %%
from sklearn import svm
classifier=svm.SVC(kernel='linear',gamma='auto',C=2)
classifier.fit(X_train,z_train) 
z_predict=classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(z_test,z_predict))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        70
#            2       0.71      1.00      0.83       170
#
#    micro avg       0.71      0.71      0.71       240
#    macro avg       0.35      0.50      0.41       240
# weighted avg       0.50      0.71      0.59       240
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(z_test,z_predict))
# Out:
# Accuracy: 0.7083333333333334
